# %%
#Imports
import os
import numpy as np
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import math
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# # New Data

# %%
#Read in data
csvFilePath="csvFilePath="/data/PHOSP/PHOSPFinalVersion.csv""
df = pd.read_csv(csvFilePath)
df.fillna(method = 'ffill',inplace = True)

# %%
len(df)
# Out:
# 1681

# %%
len(df['image_list'][0])
# Out:
# 671540

# %%
if df['image_list'][0]==df['image_list'][3]:
    print("same")
else:
    print("different")
# Out:
# different

# %%
#Transform the data into images and plot one to see

imgs = []
for i in range(0,10):

    img = df['image_list'][i].split()
    img = ['0' if x == '' else x for x in img]
    imgs.append(img)

# %%
len(imgs)
# Out:
# 10

# %%
if imgs[1]==imgs[3]:
    print("same")

# %%
image_list = np.array(imgs,dtype = 'float')
image_list.shape
# Out:
# (10, 262144)

# %%
X_train = image_list.reshape(-1,512,512,1)
X_train.shape
# Out:
# (10, 512, 512, 1)

# %%
plt.imshow(X_train[1],cmap='gray')
plt.show()

# %%
plt.imshow(X_train[4],cmap='gray')
plt.show()

# %%
plt.imshow(X_train[-1],cmap='gray')
plt.show()
